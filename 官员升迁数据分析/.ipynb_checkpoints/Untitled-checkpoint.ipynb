# %%
import pandas as pd

# %%
import pyecharts

# %%
df = pd.read_excel('逻辑选择结果.xlsx')

# %%
def clean_name(x):
    if x[-1] == '市':
        return x[:-1]
    else:
        return x

# %%
df['CITY'] = df['CITY'].apply(clean_name)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add(
        "PROMO_IN",
        [list(z) for z in zip(df['CITY'] ,df['PROMO_IN'])],
        "china-cities",
        is_map_symbol_show = False,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-中国地图（带城市）"),
        visualmap_opts=opts.VisualMapOpts(max_=1, is_piecewise=False),
    )
    .add(
        "PROMO",
        [list(z) for z in zip(df['CITY'] ,df['PROMO'])],
        "china-cities",
        is_map_symbol_show = False,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-中国地图（带城市）"),
        visualmap_opts=opts.VisualMapOpts(max_=1, is_piecewise=False),
    )
    
    
    
    
    
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china-cities':'https://assets.pyecharts.org/assets/maps/china-cities'
#         }
#     });
# </script>
#
#         <div id="8ecc6763d08944d18995e35b6263bc9f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china-cities'], function(echarts) {
#                 var chart_8ecc6763d08944d18995e35b6263bc9f = echarts.init(
#                     document.getElementById('8ecc6763d08944d18995e35b6263bc9f'), 'white', {renderer: 'canvas'});
#                 var option_8ecc6763d08944d18995e35b6263bc9f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "PROMO_IN",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china-cities",
#             "data": [
#                 {
#                     "name": "\u4e1c\u8425",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u6d4e\u5b81",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6ee8\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5fb7\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u70df\u53f0",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6d4e\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6f4d\u574a",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5408\u80a5",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6dc4\u535a",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e34\u6c82",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u804a\u57ce",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u90a2\u53f0",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5a01\u6d77",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cf0\u5b89",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u83cf\u6cfd",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8302\u540d",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u54c8\u5c14\u6ee8",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6fee\u9633",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u83b1\u829c",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u67a3\u5e84",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u65e5\u7167",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e34\u6c82",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u4e39\u4e1c",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u671d\u9633",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8bb8\u660c",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u8fde\u4e91\u6e2f",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8425\u53e3",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5ffb\u5dde",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u592a\u539f",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u8fd0\u57ce",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e34\u6c7e",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6714\u5dde",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5415\u6881",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9633\u6cc9",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u664b\u57ce",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u897f\u5b81",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u664b\u4e2d",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u5927\u540c",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u957f\u6cbb",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9647\u5357",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u547c\u548c\u6d69\u7279",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9102\u5c14\u591a\u65af",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6500\u679d\u82b1",
#                     "value": 1
#                 },
#                 {
