# %%
import pandas as pd

# %%
import pyecharts

# %%
df = pd.read_excel('逻辑选择结果.xlsx')

# %%
df
# Out:
#             CITY  PROMO  PROMO_IN
# 0             东营      1         0
# 1             济宁      1         1
# 2             滨州      1         1
# 3             德州      1         1
# 4             烟台      1         1
# 5             济南      1         1
# 6             郑州      1         1
# 7             潍坊      1         1
# 8             合肥      1         1
# 9             淄博      1         1
# 10            临沂      1         1
# 11            聊城      1         1
# 12            邢台      1         1
# 13            青岛      1         1
# 14            西安      1         1
# 15            威海      1         1
# 16            上海      1         1
# 17            泰安      1         1
# 18            北京      1         1
# 19            菏泽      1         1
# 20            武汉      1         1
# 21            厦门      1         1
# 22            茂名      1         1
# 23            深圳      1         1
# 24            天津      1         1
# 25            长沙      1         1
# ...

# %%
def clean_name(x):
    if x[-1] == '市':
        return x[:-1]
    else:
        return x

# %%
import numpy as np
def clean_value(x):
    if x == 1:
        return 1
    else:
        return np.nan

# %%
df['CITY'] = df['CITY'].apply(clean_name)

df['PROMO_IN'] = df['PROMO_IN'].apply(clean_value)
df['PROMO'] = df['PROMO'].apply(clean_value)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add(
        "PROMO_IN",
        [list(z) for z in zip(df['CITY'] ,df['PROMO_IN'])],
        "china-cities",
        is_map_symbol_show = False,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-中国地图（带城市）"),
        visualmap_opts=opts.VisualMapOpts(max_=1, is_piecewise=False),
    )
    .add(
        "PROMO",
        [list(z) for z in zip(df['CITY'] ,df['PROMO'])],
        "china-cities",
        is_map_symbol_show = False,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-中国地图（带城市）"),
        visualmap_opts=opts.VisualMapOpts(max_=1, is_piecewise=False),
    )
    
    
    
    
    
)

c.render('res.html')
# Out:
# 'F:\\中国地图绘制\\res.html'
